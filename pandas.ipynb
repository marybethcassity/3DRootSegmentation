# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\1viewsummary.xlsx',sheet_name = 'uncut')

df2 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\1viewsummary.xlsx',sheet_name = 'uncutDBSCAN')

df3 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\1viewsummary.xlsx',sheet_name = 'cut')

df4 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\1viewsummary.xlsx',sheet_name = 'cutDBSCAN')

fig, axes = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(hspace=0.7)
fig.axes[0].set_ylabel('Dice')
fig.axes[2].set_ylabel('Dice')

ax = df.plot.bar(ax=axes[0,0], x = 'Percent', legend = False)
ax.set_ylim(0.6,1)
ax.set(xlabel="Percent of total dataset")
ax.set_title("Full plant")

ax2 = df2.plot.bar(ax=axes[0,1], x = 'Percent', legend = False)
ax2.set_ylim(0.6,1)
ax2.set(xlabel="Percent of total dataset")
ax2.set_title("Full plant with DBSCAN")

ax3 = df3.plot.bar(ax=axes[1,0], x = 'Percent', legend = False)
ax3.set_ylim(0.6,1)
ax3.set(xlabel="Percent of total dataset")
ax3.set_title("Root only")

ax4 = df4.plot.bar(ax=axes[1,1], x = 'Percent', legend = False)
ax4.set_ylim(0.6,1)
ax4.set(xlabel="Percent of total dataset")
ax4.set_title("Root only with DBSCAN")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='center right', bbox_to_anchor=(1.1, 0.5))

# %%
fig.savefig(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\percents.png',bbox_inches='tight')

# %%
df = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics.xlsx',sheet_name = 'Onion1')

df2 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN.xlsx',sheet_name = 'Onion1')

df3 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics_cut.xlsx',sheet_name = 'Onion1')

df4 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN_cut.xlsx',sheet_name = 'Onion1')

df = df.drop(columns = ['cut','precision','recall','iou'])
df2 = df2.drop(columns = ['cut','precision','recall','iou'])
df3 = df3.drop(columns = ['cut_bottom','cut_top','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1
df4 = df4.drop(columns = ['cut_bottom','cut_top','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1

fig, axes = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(hspace=0.7)
plt.suptitle('Onion1')
fig.axes[0].set_ylabel('Dice')
fig.axes[2].set_ylabel('Dice')

ax = df.plot.bar(ax=axes[0,0], x = 'View', legend = False)
ax.set(xlabel="View")
ax.set_title("Full plant")
ax.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax2 = df2.plot.bar(ax=axes[0,1], x = 'View', legend = False)
ax2.set(xlabel="View")
ax2.set_title("Full plant with DBSCAN")
ax2.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax3 = df3.plot.bar(ax=axes[1,0], x = 'View', legend = False)
ax3.set(xlabel="View")
ax3.set_title("Root only")
ax3.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax4 = df4.plot.bar(ax=axes[1,1], x = 'View', legend = False)
ax4.set(xlabel="View")
ax4.set_title("Root only with DBSCAN")
ax4.set_yticks([0.0,0.25,0.50,0.75,1.0])

# %%
fig.savefig(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\Onion1.png',bbox_inches='tight')

# %%
df = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics.xlsx',sheet_name = 'Oasis4')

df2 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN.xlsx',sheet_name = 'Oasis4')

df3 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics_cut.xlsx',sheet_name = 'Oasis4')

df4 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN_cut.xlsx',sheet_name = 'Oasis4')

df = df.drop(columns = ['cut','precision','recall','iou'])
df2 = df2.drop(columns = ['cut','precision','recall','iou'])
df3 = df3.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1
df4 = df4.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1

fig, axes = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(hspace=0.7)
plt.suptitle('Oasis4')
fig.axes[0].set_ylabel('Dice')
fig.axes[2].set_ylabel('Dice')

ax = df.plot.bar(ax=axes[0,0], x = 'View', legend = False)
ax.set(xlabel="View")
ax.set_title("Full plant")
ax.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax2 = df2.plot.bar(ax=axes[0,1], x = 'View', legend = False)
ax2.set(xlabel="View")
ax2.set_title("Full plant with DBSCAN")
ax2.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax3 = df3.plot.bar(ax=axes[1,0], x = 'View', legend = False)
ax3.set(xlabel="View")
ax3.set_title("Root only")
ax3.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax4 = df4.plot.bar(ax=axes[1,1], x = 'View', legend = False)
ax4.set(xlabel="View")
ax4.set_title("Root only with DBSCAN")
ax4.set_yticks([0.0,0.25,0.50,0.75,1.0])

# %%
fig.savefig(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\Oasis4.png',bbox_inches='tight')

# %%
df = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics.xlsx',sheet_name = 'Onion2')

df2 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN.xlsx',sheet_name = 'Onion2')

df3 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics_cut.xlsx',sheet_name = 'Onion2')

df4 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN_cut.xlsx',sheet_name = 'Onion2')

df = df.drop(columns = ['cut','precision','recall','iou'])
df2 = df2.drop(columns = ['cut','precision','recall','iou'])
df3 = df3.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1
df4 = df4.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1

fig, axes = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(hspace=0.7)
plt.suptitle('Onion2')
fig.axes[0].set_ylabel('Dice')
fig.axes[2].set_ylabel('Dice')

ax = df.plot.bar(ax=axes[0,0], x = 'View', legend = False)
ax.set(xlabel="View")
ax.set_title("Full plant")
ax.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax2 = df2.plot.bar(ax=axes[0,1], x = 'View', legend = False)
ax2.set(xlabel="View")
ax2.set_title("Full plant with DBSCAN")
ax2.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax3 = df3.plot.bar(ax=axes[1,0], x = 'View', legend = False)
ax3.set(xlabel="View")
ax3.set_title("Root only")
ax3.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax4 = df4.plot.bar(ax=axes[1,1], x = 'View', legend = False)
ax4.set(xlabel="View")
ax4.set_title("Root only with DBSCAN")
ax4.set_yticks([0.0,0.25,0.50,0.75,1.0])

# %%
fig.savefig(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\Onion2.png',bbox_inches='tight')

# %%
df = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics.xlsx',sheet_name = 'Oasis5')

df2 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN.xlsx',sheet_name = 'Oasis5')

df3 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetrics_cut.xlsx',sheet_name = 'Oasis5')

df4 = pd.read_excel(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\100\3view\outputMetricsDBSCAN_cut.xlsx',sheet_name = 'Oasis5')

df = df.drop(columns = ['cut','precision','recall','iou'])
df2 = df2.drop(columns = ['cut','precision','recall','iou'])
df3 = df3.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1
df4 = df4.drop(columns = ['cut','precision','recall','iou']) #columns = ['cut_bottom','cut_top','precision','recall','iou'] if Onion1

fig, axes = plt.subplots(nrows=2, ncols=2)
plt.subplots_adjust(hspace=0.7)
plt.suptitle('Oasis5')
fig.axes[0].set_ylabel('Dice')
fig.axes[2].set_ylabel('Dice')

ax = df.plot.bar(ax=axes[0,0], x = 'View', legend = False)
ax.set(xlabel="View")
ax.set_title("Full plant")
ax.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax2 = df2.plot.bar(ax=axes[0,1], x = 'View', legend = False)
ax2.set(xlabel="View")
ax2.set_title("Full plant with DBSCAN")
ax2.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax3 = df3.plot.bar(ax=axes[1,0], x = 'View', legend = False)
ax3.set(xlabel="View")
ax3.set_title("Root only")
ax3.set_yticks([0.0,0.25,0.50,0.75,1.0])

ax4 = df4.plot.bar(ax=axes[1,1], x = 'View', legend = False)
ax4.set(xlabel="View")
ax4.set_title("Root only with DBSCAN")
ax4.set_yticks([0.0,0.25,0.50,0.75,1.0])

# %%
fig.savefig(r'C:\Users\Mary Beth Cassity\OneDrive - Auburn University\Grad\AgCypher Lab\RootAI\predictions\Oasis5.png',bbox_inches='tight')
